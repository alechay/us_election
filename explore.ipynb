# %% [raw]
# %conda list

# %%
import pandas as pd

# %%
df=pd.read_csv('county/countypres_2000-2016.csv')
df.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
df['party'].value_counts()
# Out:
# democrat      15789
# republican    15789
# green          3157
# Name: party, dtype: int64

# %%
df['percent']=df['candidatevotes']/df['totalvotes']

# %%
dem2000=df.loc[
    (df['party']=='democrat')
    &(df['year']==2000)]
dem2000.head()
# Out:
#     year    state state_po   county    FIPS     office candidate     party  \
# 0   2000  Alabama       AL  Autauga  1001.0  President   Al Gore  democrat
# 4   2000  Alabama       AL  Baldwin  1003.0  President   Al Gore  democrat
# 8   2000  Alabama       AL  Barbour  1005.0  President   Al Gore  democrat
# 12  2000  Alabama       AL     Bibb  1007.0  President   Al Gore  democrat
# 16  2000  Alabama       AL   Blount  1009.0  President   Al Gore  democrat
#
#     candidatevotes  totalvotes   version   percent
# 0           4942.0       17208  20191203  0.287192
# 4          13997.0       56480  20191203  0.247822
# 8           5188.0       10395  20191203  0.499086
# 12          2710.0        7101  20191203  0.381636
# 16          4977.0       17973  20191203  0.276915

# %%
dem2000.loc[dem2000['state']=='Texas']
# Out:
#        year  state state_po    county     FIPS     office candidate     party  \
# 9972   2000  Texas       TX  Anderson  48001.0  President   Al Gore  democrat
# 9976   2000  Texas       TX   Andrews  48003.0  President   Al Gore  democrat
# 9980   2000  Texas       TX  Angelina  48005.0  President   Al Gore  democrat
# 9984   2000  Texas       TX   Aransas  48007.0  President   Al Gore  democrat
# 9988   2000  Texas       TX    Archer  48009.0  President   Al Gore  democrat
# ...     ...    ...      ...       ...      ...        ...       ...       ...
# 10968  2000  Texas       TX      Wood  48499.0  President   Al Gore  democrat
# 10972  2000  Texas       TX    Yoakum  48501.0  President   Al Gore  democrat
# 10976  2000  Texas       TX     Young  48503.0  President   Al Gore  democrat
# 10980  2000  Texas       TX    Zapata  48505.0  President   Al Gore  democrat
# 10984  2000  Texas       TX    Zavala  48507.0  President   Al Gore  democrat
#
# ...

# %%
# Here we load a GeoJSON file containing the geometry information for US counties, 
# where feature.id is a FIPS code.

from urllib.request import urlopen
import json
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

# %%
geo=pd.DataFrame.from_dict(counties['features'])
geo.head()
# Out:
#       type                                         properties  \
# 0  Feature  {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1  Feature  {'GEO_ID': '0500000US01009', 'STATE': '01', 'C...
# 2  Feature  {'GEO_ID': '0500000US01017', 'STATE': '01', 'C...
# 3  Feature  {'GEO_ID': '0500000US01021', 'STATE': '01', 'C...
# 4  Feature  {'GEO_ID': '0500000US01033', 'STATE': '01', 'C...
#
#                                             geometry     id
# 0  {'type': 'Polygon', 'coordinates': [[[-86.4967...  01001
# 1  {'type': 'Polygon', 'coordinates': [[[-86.5777...  01009
# 2  {'type': 'Polygon', 'coordinates': [[[-85.1841...  01017
# 3  {'type': 'Polygon', 'coordinates': [[[-86.5173...  01021
# 4  {'type': 'Polygon', 'coordinates': [[[-88.1399...  01033

# %%
pd.read_json('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json')
# Out:
#                    type                                           features
# 0     FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 1     FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 2     FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3     FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 4     FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# ...                 ...                                                ...
# 3216  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3217  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3218  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3219  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3220  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
#
# [3221 rows x 2 columns]

# %%
import plotly.graph_objects as go # or plotly.express as px
import plotly.express as px

fig = px.choropleth_mapbox(dem2000, geojson=counties, locations='FIPS', color='percent',
                           color_continuous_scale="Viridis",
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=0.5,
                           labels={'percent':'percentage'}
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

import dash
import dash_core_components as dcc
import dash_html_components as html

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig)
])

app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
